# %% [markdown]
# <a href="https://colab.research.google.com/github/jaspia-1/DIP_LAB/blob/main/task_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab.patches import cv2_imshow
import cv2
import matplotlib.pyplot as plt
import numpy as np

def transform(img):
  row, col, channel = img.shape

  img2 = np.zeros((row, col), dtype=np.uint8)

  for i in range(row):
    for j in range(col):
      r, g, b = img[i, j]
      img2[i, j] = r * 0.2126 + g * 0.7152 + b * 0.0722

  return img2

img = cv2.imread('DIP_Lab_task_02.jpg')
img2 = transform(img)

plt.figure(figsize=(5, 5))
plt.subplot(1, 2, 1)
plt.imshow(img, cmap='gray')
plt.axis('off')
plt.title('RGB Image')
plt.subplot(1, 2, 2)
plt.imshow(img2, cmap='gray')
plt.axis('off')
plt.title('Gray Scale Image')
# Out:
# Text(0.5, 1.0, 'Gray Scale Image')
